# %%
# Import preliminaries
import pandas as pd
from sqlalchemy import create_engine, inspect
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import func

# %% [markdown]
# ### Store Annual Health Data CSV into DataFrame

# %%
health_csv = "annual_report.csv"
health_df = pd.read_csv(health_csv)
health_df.head()
# Out:
#    Edition  Report Type                   Measure Name     State Name  Rank  \
# 0     2019  2019 Annual  Adverse Childhood Experiences         Alaska  34.0
# 1     2019  2019 Annual  Adverse Childhood Experiences        Alabama  46.0
# 2     2019  2019 Annual  Adverse Childhood Experiences  United States   NaN
# 3     2019  2019 Annual  Adverse Childhood Experiences       Arkansas  47.0
# 4     2019  2019 Annual  Adverse Childhood Experiences        Arizona  48.0
#
#    Value  Score  Lower CI  Upper CI  \
# 0   24.1   0.96      27.7      20.5
# 1   26.3   1.56      30.1      22.5
# 2   20.5    NaN      21.2      19.8
# 3   27.1   1.76      30.8      23.3
# 4   27.3   1.82      31.1      23.4
#
#                                               Source Source Year
# 0  U.S. HHS, HRSA, Maternal and Child Health Bure...   2016-2017
# 1  U.S. HHS, HRSA, Maternal and Child Health Bure...   2016-2017
# 2  U.S. HHS, HRSA, Maternal and Child Health Bure...   2016-2017
# 3  U.S. HHS, HRSA, Maternal and Child Health Bure...   2016-2017
# 4  U.S. HHS, HRSA, Maternal and Child Health Bure...   2016-2017

# %% [markdown]
# ### Clean up the columns

# %%
health_df = health_df[['State Name', 'Rank', 'Measure Name', 'Score', 'Source', 'Source Year']].copy()
health_df.head()
# Out:
#       State Name  Rank                   Measure Name  Score  \
# 0         Alaska  34.0  Adverse Childhood Experiences   0.96
# 1        Alabama  46.0  Adverse Childhood Experiences   1.56
# 2  United States   NaN  Adverse Childhood Experiences    NaN
# 3       Arkansas  47.0  Adverse Childhood Experiences   1.76
# 4        Arizona  48.0  Adverse Childhood Experiences   1.82
#
#                                               Source Source Year
# 0  U.S. HHS, HRSA, Maternal and Child Health Bure...   2016-2017
# 1  U.S. HHS, HRSA, Maternal and Child Health Bure...   2016-2017
# 2  U.S. HHS, HRSA, Maternal and Child Health Bure...   2016-2017
# 3  U.S. HHS, HRSA, Maternal and Child Health Bure...   2016-2017
# 4  U.S. HHS, HRSA, Maternal and Child Health Bure...   2016-2017

# %% [markdown]
# ### Isolate each Health Measure Name of interest (mental illness, insufficient sleep, air_pollution)

# %%
health_mental_df = health_df.loc[health_df['Measure Name']=='Mental illness', :]
health_mental_df = health_mental_df.sort_values(by='State Name', ascending=True)
health_mental_df = health_mental_df.rename(columns={"State Name":"state", 'Measure Name': 'measure_name', 'Source Year': 'source_year'})
health_mental_df = health_mental_df.reset_index(drop=True)
health_mental_df.head()
# Out:
#         state  Rank    measure_name  Score  \
# 0     Alabama  14.0  Mental illness   0.05
# 1      Alaska  45.0  Mental illness   1.94
# 2     Arizona  28.0  Mental illness   0.45
# 3    Arkansas  41.0  Mental illness   1.59
# 4  California   3.0  Mental illness  -1.00
#
#                                               Source source_year
# 0  U.S. HHS, HRSA, Maternal and Child Health Bure...   2016-2017
# 1  U.S. HHS, HRSA, Maternal and Child Health Bure...   2016-2017
# 2  U.S. HHS, HRSA, Maternal and Child Health Bure...   2016-2017
# 3  U.S. HHS, HRSA, Maternal and Child Health Bure...   2016-2017
# 4  U.S. HHS, HRSA, Maternal and Child Health Bure...   2016-2017

# %%
health_sleep_df = health_df.loc[health_df['Measure Name']=='Insufficient Sleep', :]
health_sleep_df = health_sleep_df.sort_values(by='State Name', ascending=True)
health_sleep_df = health_sleep_df.rename(columns={"State Name":"state", 'Measure Name': 'measure_name', 'Source Year': 'source_year'})
health_sleep_df = health_sleep_df.reset_index(drop=True)
health_sleep_df.head()
# Out:
#         state  Rank        measure_name  Score  \
# 0     Alabama  43.0  Insufficient Sleep   1.21
# 1      Alaska  20.0  Insufficient Sleep  -0.30
# 2     Arizona  22.0  Insufficient Sleep  -0.15
# 3    Arkansas  29.0  Insufficient Sleep   0.47
# 4  California  25.0  Insufficient Sleep  -0.03
#
#                                             Source source_year
# 0  CDC, Behavioral Risk Factor Surveillance System        2018
# 1  CDC, Behavioral Risk Factor Surveillance System        2018
# 2  CDC, Behavioral Risk Factor Surveillance System        2018
# 3  CDC, Behavioral Risk Factor Surveillance System        2018
# 4  CDC, Behavioral Risk Factor Surveillance System        2018

# %%
health_airpollution_df = health_df.loc[health_df['Measure Name']=='Air Pollution', :]
health_airpollution_df = health_airpollution_df.sort_values(by='State Name', ascending=True)
health_airpollution_df = health_airpollution_df.rename(columns={"State Name":"state", 'Measure Name': 'measure_name', 'Source Year': 'source_year'})
health_airpollution_df = health_airpollution_df.reset_index(drop=True)
health_airpollution_df.head()
# Out:
#         state  Rank   measure_name  Score  \
# 0     Alabama  36.0  Air Pollution  -0.21
# 1      Alaska  10.0  Air Pollution  -1.40
# 2     Arizona  49.0  Air Pollution   0.91
# 3    Arkansas  19.0  Air Pollution  -0.91
# 4  California  50.0  Air Pollution   2.00
#
#                                               Source source_year
# 0  U.S. Environmental Protection Agency; U.S. Cen...   2016-2018
# 1  U.S. Environmental Protection Agency; U.S. Cen...   2016-2018
# 2  U.S. Environmental Protection Agency; U.S. Cen...   2016-2018
# 3  U.S. Environmental Protection Agency; U.S. Cen...   2016-2018
# 4  U.S. Environmental Protection Agency; U.S. Cen...   2016-2018

# %%
df_col ={'health_mental_df': 'mentalill', 'health_sleep_df':'sleep', 'health_airpollution_df': 'pollution'}
for key, value in df_col.items():
    df = globals()[key]
    df.columns = ['{}_'.format(value)+col_name for col_name in df.columns]

# %%
health_airpollution_df.head()
health_airpollution_df.count()
# Out:
# pollution_state           52
# pollution_Rank            50
# pollution_measure_name    52
# pollution_Score           50
# pollution_Source          52
# pollution_source_year     52
# dtype: int64

# %%
health_mental_df.head()
health_mental_df.count()
# Out:
# mentalill_state           52
# mentalill_Rank            50
# mentalill_measure_name    52
# mentalill_Score           50
# mentalill_Source          52
# mentalill_source_year     52
# dtype: int64

# %%
health_sleep_df.head()
health_sleep_df.count()
# Out:
# sleep_state           52
# sleep_Rank            50
# sleep_measure_name    52
# sleep_Score           50
# sleep_Source          52
# sleep_source_year     52
# dtype: int64

# %% [markdown]
# ### Store State Happiness Ranking Data

# %%
happiness_csv = "happiness.csv"
happiness_df = pd.read_csv(happiness_csv)
happiness_df = happiness_df.rename(columns={"State":"state"})
happiness_df = happiness_df.sort_values(by='state', ascending=True)
happiness_df = happiness_df.reset_index(drop=True)
happiness_df.head()
# Out:
#    overall       state  totalScore  emotAndPhysRank  workEnvironRank  \
# 0       45     Alabama       39.35               46               39
# 1       47      Alaska       38.21               33               49
# 2       21     Arizona       52.92               27               12
# 3       49    Arkansas       36.61               50               29
# 4        5  California       63.14                4               24
#
#    communityAndEnvironRank       Pop
# 0                       43   4898246
# 1                       50    735720
# 2                       34   7275070
# 3                       23   3026412
# 4                       12  39747267
